# %% [markdown]
# # Setup

# %%
import pymongo
import statistics
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from datetime import timedelta
from iso8601 import parse_date

sns.set_theme(style="darkgrid")

season_start = parse_date("2020-07-01T21:22:25.947Z") - timedelta(minutes=30)
season_end = parse_date("2020-07-18T21:11:21.615Z") + timedelta(minutes=30)

client = pymongo.MongoClient()
db = client.tpp3
collection = db.matches.find({"finished_at": {"$gt": season_start, "$lt": season_end}})
data = pd.DataFrame(list(collection))
keys = list(data.keys())
to_drop = ["game","avatars","teams","base_metagames","base_gimmicks"]
for i in to_drop:
    if i in keys:
        data = data.drop([i], axis=1)

data.result = pd.to_numeric(data.result, errors="coerce")

data["duration"] = data.finished_at - data.started_at
data = data.drop(["started_at","finished_at","created_at"],axis=1)

data[["odds","blue_odds"]] = pd.DataFrame(data.pokeyen_odds.to_list(), index=data.index)
data["winner_odds"] = [data.odds[i] if result==1 else data.blue_odds[i] for i,result in enumerate(data["result"])]
data = data.drop(["pokeyen_odds","blue_odds"],axis=1)

data["num_bettors"] = data.pokeyen_bets.str.len() # magic I guess
data = data.drop(["pokeyen_bets"], axis=1)

# TODO there has to be a better way
average_bet = []
total_bonus = []
collection = db.matches.find({"finished_at": {"$gt": season_start, "$lt": season_end}}) # it broke without resetting collection here
for i, match in enumerate(collection):
    average_bet.append(0.0 if len(match["pokeyen_bets"]) == 0
        else statistics.mean(v["amount"] for v in match["pokeyen_bets"].values()))
    if "bet_bonus" in match["pokeyen_bets"]:
        total_bonus.append(0.0 if len(match["pokeyen_bets"]) == 0 or match["result"] == None
            else (sum(bet["amount"]*bet["bet_bonus"]/100 for bet in match["pokeyen_bets"].values() if bet["team"] == match["result"])))
data["average_bet"] = pd.DataFrame(average_bet)
if len(total_bonus) > 0:
    data["bet_bonus_amount"] = pd.DataFrame(total_bonus)
del average_bet

keys = list(data.keys())
nonzero_bets = data[data.average_bet > 0]

data.info()
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2368 entries, 0 to 2367
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               2368 non-null   int64
#  1   result            2349 non-null   float64
#  2   stage             2368 non-null   object
#  3   metagame          2368 non-null   object
#  4   gimmick           2368 non-null   object
#  5   switching         2368 non-null   object
#  6   custom            2368 non-null   bool
#  7   result_overrides  2 non-null      object
#  8   duration          2368 non-null   timedelta64[ns]
#  9   odds              2368 non-null   float64
#  10  winner_odds       2368 non-null   float64
#  11  num_bettors       2368 non-null   int64
#  12  average_bet       2368 non-null   float64
# dtypes: bool(1), float64(4), int64(2), object(5), timedelta64[ns](1)
# memory usage: 224.4+ KB
#          _id  result       stage   metagame  \
# 0     149331     0.0     gateway     simple
# 1     149332     1.0  sunny_park     simple
# 2     149333     1.0     crystal   pbr_gold
# 3     149334     0.0     crystal   advanced
# 4     149335     1.0        neon   advanced
# ...      ...     ...         ...        ...
# 2363  151698     1.0      lagoon     simple
# 2364  151699     1.0        neon     simple
# 2365  151700     1.0       magma     simple
# 2366  151701     1.0        neon        pwt
# 2367  151702     0.0  sunny_park  metronome
#
#                                       gimmick switching  custom  \
# 0                                     spanish     never   False
# 1                                      german    always   False
# 2                         japanese_combo_of_3     never   False
# 3                                      french     never   False
# 4                                     italian     never   False
# ...                                       ...       ...     ...
# 2363            sync5050+german_autogenerated     never   False
# 2364                                 japanese    always   False
# 2365  singles_combo_of_2+german_autogenerated    always   False
# 2366                                   french     never   False
# 2367         blind_bet+japanese_autogenerated     never    True
#
#      result_overrides               duration      odds  winner_odds  \
# 0                 NaN 0 days 00:03:34.884000  0.845361     1.182927
# 1                 NaN 0 days 00:06:43.294000  0.816473     0.816473
# 2                 NaN 0 days 00:05:46.239000  1.984505     1.984505
# 3                 NaN 0 days 00:06:45.490000  1.756934     0.569173
# 4                 NaN 0 days 00:03:44.040000  2.234364     2.234364
# ...               ...                    ...       ...          ...
# 2363              NaN 0 days 00:04:08.295000  0.678610     0.678610
# 2364              NaN 0 days 00:05:30.910000  2.778958     2.778958
# 2365              NaN 0 days 00:07:20.262000  0.726243     0.726243
# 2366              NaN 0 days 00:03:16.709000  7.093806     7.093806
# 2367              NaN 0 days 00:05:21.045000  0.854709     1.169988
#
#       num_bettors  average_bet
# 0              53  1013.207547
# 1              51   854.490196
# 2              55   998.072727
# 3              49  1083.306122
# 4              55   985.363636
# ...           ...          ...
# 2363           48  1080.500000
# 2364           41  1215.073171
# 2365           52  1357.557692
# 2366           60  4322.766667
# 2367           72  3921.138889
#
# [2368 rows x 13 columns]

# %% [markdown]
# # Highlights

# %% [markdown]
# ### Match with the least bidders

# %%
data[data.num_bettors == data.num_bettors.min()]
# Out:
#          _id  result    stage metagame                         gimmick  \
# 1590  150924     0.0  crystal   simple  fragile+japanese_autogenerated
#
#      switching  custom result_overrides               duration      odds  \
# 1590     never    True              NaN 0 days 00:05:40.765000  0.864615
#
#       winner_odds  num_bettors  average_bet
# 1590     1.156584            6        404.0

# %% [markdown]
# ### Match with the lowest average bet

# %%
data[data.average_bet == data.average_bet.min()]
# Out:
#          _id  result   stage metagame gimmick switching  custom  \
# 1358  150691     1.0  lagoon   simple  french     never    True
#
#      result_overrides               duration      odds  winner_odds  \
# 1358              NaN 0 days 00:04:41.077000  1.259471     1.259471
#
#       num_bettors  average_bet
# 1358           14        311.0

# %% [markdown]
# ### Match with the lowest Red odds

# %%
data[data.odds == data.odds.max()]
# Out:
#          _id  result      stage metagame                            gimmick  \
# 1287  150620     1.0  waterfall   simple  commitment+japanese_autogenerated
#
#      switching  custom result_overrides               duration      odds  \
# 1287     never   False              NaN 0 days 00:03:45.418000  36.22293
#
#       winner_odds  num_bettors  average_bet
# 1287     36.22293           18       8766.0

# %% [markdown]
# ### Match with the most bidders

# %%
data[data.num_bettors == data.num_bettors.max()]
# Out:
#          _id  result       stage   metagame                           gimmick  \
# 2367  151702     0.0  sunny_park  metronome  blind_bet+japanese_autogenerated
#
#      switching  custom result_overrides               duration      odds  \
# 2367     never    True              NaN 0 days 00:05:21.045000  0.854709
#
#       winner_odds  num_bettors  average_bet
# 2367     1.169988           72  3921.138889

# %% [markdown]
# ### Match with the highest average bet

# %%
data[data.average_bet == data.average_bet.max()]
# Out:
#         _id  result    stage metagame gimmick switching  custom  \
# 870  150202     0.0  gateway      pwt  french     never   False
#
#     result_overrides               duration      odds  winner_odds  \
# 870              NaN 0 days 00:05:47.020000  0.054704    18.280216
#
#      num_bettors  average_bet
# 870           16   12741.8125

# %% [markdown]
# ### Match with the highest red odds

# %%
data[data.odds == data.odds.min()]
# Out:
#         _id  result    stage metagame            gimmick switching  custom  \
# 854  150186     0.0  gateway   simple  french_combo_of_3     never    True
#
#     result_overrides               duration      odds  winner_odds  \
# 854              NaN 0 days 00:04:42.308000  0.022967    43.539788
#
#      num_bettors  average_bet
# 854           35  3246.314286

# %% [markdown]
# # Data over time

# %%
ax = data.plot(y="num_bettors",figsize=(14,7), title="Number of bettors over time")
sns.regplot(x=data.index, y=data.num_bettors, scatter=False, ax=ax)
# sns.kdeplot(y=data.num_bettors)
plt.show()

# %%
ax = nonzero_bets.plot(y="average_bet", logy=True, figsize=(14,7), title="Average bet over time")
sns.regplot(x=nonzero_bets.index, y=nonzero_bets.average_bet, scatter=False, ax=ax)
ax.set(ylabel="Average bet (logarithmic)")
plt.show()

# %%
def fill_plot():
    g.refline(x=x.mean(), linestyle=":")
    g.refline(x=x.median(), y=y.median(), linestyle="-")
    sns.stripplot(x=x, y=y, s=5, ax=g.ax_joint)
    sns.kdeplot(x=x, ax=g.ax_marg_x)
    sns.kdeplot(y=y, ax=g.ax_marg_y)
    plt.xticks(rotation=90)
    
x, y = nonzero_bets.num_bettors, nonzero_bets.average_bet

f = plt.figure()
g = sns.JointGrid(x=x, y=y,
                   xlim=(nonzero_bets.num_bettors.min()-1,nonzero_bets.num_bettors.max()+1),
                   height=10,
                  )
g.ax_joint.set_yscale("log")
fill_plot()

median_thresh = y.median() * 2
if(y.max() > median_thresh * 10):
    f = plt.figure()
    g = sns.JointGrid(x=x, y=y,
                    xlim=(nonzero_bets.num_bettors.min()-1,nonzero_bets.num_bettors.max()+1),
                    height=10,
                    ylim=((-0.1*median_thresh),median_thresh)
                  )
    fill_plot()

plt.show()

# %%
if "metagame" in keys:
    f = plt.figure(figsize=(10,7))
    f.suptitle("When each metagame was played")
    ax = sns.scatterplot(x=data.index,y=data.metagame)
    ax.set(xlabel="Match #")
    plt.show()
else:
    print("No metagames this season :(")

# %% [markdown]
# # Metagames

# %% [markdown]
# ## Setup

# %%
if "metagame" in keys:
    threshold = 0.005 * data.index.max() # remove metagames that appear less than this amount of times, since they are likely token matches
    meta = nonzero_bets[nonzero_bets.groupby("metagame").metagame.transform("count") > threshold]
    metagames = nonzero_bets.metagame.unique().tolist()
    for m in meta.metagame.unique().tolist():
        metagames.remove(m)
    print("removed very rare metagames: " + str(metagames))
# Out:
# removed very rare metagames: ['starters', 'kapow', 'rough_skin', 'input_war', 'random_mix_bid3']

# %%
if "metagame" in keys:
    f = plt.figure(figsize=(len(meta.metagame.unique())/2.5,5))
    f.suptitle("Number of people betting on each metagame")
    sns.boxplot(x=meta.metagame, y=meta.num_bettors)
    plt.xticks(rotation=90)
    plt.show()

# %%
if "metagame" in keys:
    f = plt.figure(figsize=(len(meta.metagame.unique())/2.5,5))
    f.suptitle("Average bet on each metagame")
    ax = sns.boxplot(x=meta.metagame,y=meta.average_bet)
    ax.set(yscale="log", ylabel="Average bet (logarithmic)")
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# # Gimmicks

# %% [markdown]
# ## Setup

# %%
if "gimmick" in keys:
    threshold_gim = 5 # absolute minimum amount of data we need to make any meaningful insight
    gim = nonzero_bets[nonzero_bets.groupby("gimmick").gimmick.transform("count") > threshold_gim]
    gimmicks = data.gimmick.unique().tolist()
    for g in gim.gimmick.unique().tolist():
        gimmicks.remove(g)
    print("removed infrequently used gimmicks: " + str(gimmicks))
else:
    print("no gimmicks this season :(")
# Out:
# removed infrequently used gimmicks: ['german_doubles_inputting_combo_of_3', 'normal', 'clone', 'defiance', 'japanese_doubles_inputting_combo_of_4', 'japanese_doubles_inputting_combo_of_3', 'german_doubles', 'french_doubles_defiance', 'japanese_combo_of_4', 'spanish_doubles_inputting_combo_of_3', 'spanish_combo_of_4', 'french_doubles_inputting_combo_of_3', 'german_combo_of_4', 'german_doubles_inputting_combo_of_4', 'italian_doubles_inputting_combo_of_3', 'spanish_doubles_inputting_combo_of_4', 'clone+japanese_autogenerated', 'rainbow+spanish_autogenerated', 'explosive+german_autogenerated', 'doubles_inputting_combo_of_2+japanese_autogenerated', 'traitor+japanese_autogenerated', 'fog+french_autogenerated', 'timed+spanish_autogenerated', 'hit_and_run+french_autogenerated', '80_perc_hp+japanese_autogenerated', 'singles_combo_of_3+italian_autogenerated', 'random_order+german_autogenerated', 'adaptable+italian_autogenerated', 'secrecy+italian_autogenerated', 'doubles_inputting_combo_of_2+german_autogenerated', 'random_order+french_autogenerated', 'fog+german_autogenerated', 'blind_bet+italian_autogenerated', 'rainbow+italian_autogenerated', 'afflicted+french_autogenerated', 'explosive+spanish_autogenerated', 'doubles_inputting_combo_of_3+german_autogenerated', 'singles_combo_of_2+japanese_autogenerated', 'sticky_inputs+japanese_autogenerated', 'speed+italian_autogenerated', 'letdown+french_autogenerated', 'acid_rain+german_autogenerated', 'defiance+german_autogenerated', 'sticky_inputs+italian_autogenerated', 'explosive+japanese_autogenerated', 'fog+italian_autogenerated', '80_perc_hp+spanish_autogenerated', 'clone+german_autogenerated', 'shield+french_autogenerated', 'rngod+italian_autogenerated', 'commitment+german_autogenerated', 'sticky_inputs+spanish_autogenerated', 'doubles_inputting_combo_of_2+french_autogenerated', 'duel+spanish_autogenerated', 'hit_and_run+german_autogenerated', 'doubles_inputting_combo_of_3+french_autogenerated', 'fragile+italian_autogenerated', 'speed+spanish_autogenerated', 'sky_battle+italian_autogenerated', 'sky_battle+french_autogenerated', 'chameleon+german_autogenerated', 'speed+japanese_autogenerated', 'doubles_inputting_combo_of_2+spanish_autogenerated', 'singles_combo_of_2+italian_autogenerated', 'sticky_inputs+french_autogenerated', 'random_order+spanish_autogenerated', 'commitment+italian_autogenerated', 'afflicted+japanese_autogenerated', 'speed+french_autogenerated', 'fragile+japanese_autogenerated', 'commitment+spanish_autogenerated', 'rainbow+german_autogenerated', 'chameleon+french_autogenerated', 'rngod+french_autogenerated', 'armor+spanish_autogenerated', 'pinpoint+japanese_autogenerated', 'clone+italian_autogenerated', 'traitor+italian_autogenerated', 'sync5050+spanish_autogenerated', 'lucky+german_autogenerated', 'adaptable+japanese_autogenerated', 'adaptable+spanish_autogenerated', 'sync5050+japanese_autogenerated', 'secrecy+french_autogenerated', 'acid_rain+spanish_autogenerated', 'commitment+french_autogenerated', 'pinpoint+german_autogenerated', 'singles_combo_of_3+german_autogenerated', 'fog+japanese_autogenerated', 'doubles_defiance_combo_of_2+german_autogenerated', 'duel+japanese_autogenerated', 'sketchy+french_autogenerated', 'traitor+french_autogenerated', 'blind_bet+japanese_autogenerated', 'singles_combo_of_3+spanish_autogenerated', 'pinpoint+french_autogenerated', '80_perc_hp+german_autogenerated', 'doubles_defiance_combo_of_2+spanish_autogenerated', 'singles_combo_of_3+japanese_autogenerated', 'armor+german_autogenerated', 'chameleon+italian_autogenerated', 'sync5050+german_autogenerated', 'chameleon+japanese_autogenerated', 'timed+german_autogenerated', 'doubles_inputting_combo_of_3+japanese_autogenerated', 'acid_rain+italian_autogenerated', 'defiance_rngod+french_autogenerated', 'sync5050+italian_autogenerated', 'hit_and_run+italian_autogenerated', 'shield+japanese_autogenerated', 'hidden_ace+italian_autogenerated', 'secrecy+japanese_autogenerated', 'explosive+french_aut ...

# %%
if "gimmick" in keys:
    f = plt.figure(figsize=(len(gim.gimmick.unique())/2.5,5))
    f.suptitle("Number of people betting on each gimmick")
    sns.boxplot(x="gimmick",y="num_bettors",data=gim)
    plt.xticks(rotation=90)
    plt.show()

# %%
if "gimmick" in keys:
    f = plt.figure(figsize=(len(gim.gimmick.unique())/2.5,5))
    f.suptitle("Average Amount bet on each gimmick")
    ax = sns.boxplot(x=gim.gimmick, y=gim.average_bet)
    ax.set(yscale="log", ylabel="Average Amount bet (logarithmic)")
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# # Switching

# %%
sns.boxplot(x=data.switching,y=data.num_bettors)
plt.show()

# %%
ax = sns.boxplot(x=data.switching,y=data.average_bet)
ax.set(yscale="log", ylabel="Average bet (logarithmic)")
plt.show()

# %% [markdown]
# # Odds vs winner
# lower odds(<1) indicate more people bet on team 0 (probably red?), while higher(>1) odds indicate more people bet on team 1 (probably blue)

# %%
# remove entries where bets are all on 1 team
nonzero_bets = nonzero_bets[nonzero_bets.odds > 0.00001]

auto_matches = nonzero_bets[nonzero_bets.custom == False]
bid_matches = nonzero_bets[nonzero_bets.custom == True]

f, ax = plt.subplots(1, 2, figsize=(10,7),sharey=True)
f.suptitle("Odds vs Winner")
ax[0].set(yscale="log", title="random matches")
ax[1].set(title="bid matches")

sns.boxplot(x=auto_matches.result,y=auto_matches.odds, ax=ax[0])
sns.boxplot(x=bid_matches.result,y=bid_matches.odds)

plt.show()

# %% [markdown]
# # Bet bonus

# %%
if "bet_bonus_amount" in keys:
    should_draw_random_graph = auto_matches.bet_bonus_amount.mean() > 0
    should_draw_custom_graph = bid_matches.bet_bonus_amount.mean() > 0
    graphs_to_draw = should_draw_random_graph + should_draw_custom_graph
    i = 0

    f, ax = plt.subplots(graphs_to_draw, 1, figsize=(10,7),sharey=True)
    f.suptitle("Pokeyen injected from bet bonus")

    if should_draw_random_graph:
        if graphs_to_draw > 1:
            ax[i].set(yscale="log", title="random matches")
            sns.regplot(x=auto_matches.index,y=auto_matches.bet_bonus_amount, ax=ax[i])
            ax[i].set(ylabel="Pokeyen gained from bet bonus")
            i+=1
        else:
            ax.set(yscale="log", title="random matches")
            sns.regplot(x=auto_matches.index,y=auto_matches.bet_bonus_amount, ax=ax)
            ax.set(ylabel="Pokeyen gained from bet bonus")
    else:
        print("random matches had no bet bonus, skipping drawing graph")

    if should_draw_custom_graph:
        if graphs_to_draw > 1:
            ax[i].set(yscale="log", title="bid matches")
            sns.regplot(x=bid_matches.index,y=bid_matches.bet_bonus_amount, ax=ax[i])
            ax[i].set(ylabel="Pokeyen gained from bet bonus")
        else:
            ax.set(yscale="log", title="bid matches")
            sns.regplot(x=bid_matches.index,y=bid_matches.bet_bonus_amount, ax=ax)
            ax.set(ylabel="Pokeyen gained from bet bonus")
    else:
        print("bid matches had no bet bonus, skipping drawing graph")

    plt.show()

# %% [markdown]
# # Match predictability

# %%
if "metagame" in keys:
    f = plt.figure(figsize=(len(meta.metagame.unique())/2,5))
    f.suptitle("Winning odds on each metagame")
    ax = sns.boxplot(x=meta.metagame,y=meta.winner_odds, hue=meta.custom)
    ax.set(ylabel="the winning team's odds", ylim=(0,10))
    plt.xticks(rotation=90)
    plt.show()

# %%
if "gimmick" in keys:
    f = plt.figure(figsize=(len(gim.gimmick.unique())/2.5,5))
    f.suptitle("Winning odds on each gimmick")
    ax = sns.boxplot(x=gim.gimmick,y=gim.winner_odds, hue=gim.custom)
    ax.set(ylabel="the winning team's odds", ylim=(0,10))
    plt.xticks(rotation=90)
    plt.show()
